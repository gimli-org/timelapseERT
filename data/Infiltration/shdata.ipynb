# %%
from pygimli.physics import ert

# %%
self = ert.TimelapseERT("infiltration.shm")
print(self)
# Out:
# Timelapse ERT data:
# Data: Sensors: 392 data: 2849, nonzero entries: ['a', 'b', 'k', 'm', 'n', 'valid']
# 197 time steps from 2015-05-27 15:08 to 2015-06-01 09:28

# %%
self.showTimeline(a=103, b=104)
# Out:
# <Axes: xlabel='time', ylabel='resistivity (Ohmm)'>
