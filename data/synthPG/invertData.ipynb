# %%
from pygimli.physics import ert

# %%
tl = ert.TimelapseERT("synth.shm")
print(tl)
# Out:
# Timelapse ERT data:
# Data: Sensors: 41 data: 741, nonzero entries: ['a', 'b', 'm', 'n', 'valid']
# 10 time steps from 2017-01-01 00:00 to 2017-01-10 00:00

# %%
tl.fullInversion()
# Out:
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Save RVector binary
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Cache stored: C:\Guenther.T\Anwendungsdaten\pygimli\Cache\17583317146935007984
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Found 2 regions.
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Found 2 regions.
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2030 Cells: 3820 Boundaries: 2984
# 24/10/23 - 16:30:48 - pyGIMLi - INFO - Starting inversion.
# 708 model cells
# Mesh: Nodes: 2030 Cells: 3820 Boundaries: 2984
# fop: <pygimli.frameworks.timelapse.MultiFrameModelling object at 0x00000224AC65DE00>
# ...

# %%
tl.generateModelPDF()
